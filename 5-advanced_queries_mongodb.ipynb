# %% [markdown]
# # Querrying a noSQL db (MongoDB)

# %% [markdown]
# MongoDB supports both basic and advanced CRUD operations (**C**reate **R**ead **U**pdate and **D**elete).
#
# In this notebook, we'll explore the **Read** operations - specifically, how to query an existing collection of documents in MongoDB.
#
# >NOTE: For more information on MongoDB's support for query operations, see [here]( https://docs.mongodb.com/manual/tutorial/query-documents/.).

# %% [markdown]
# ## Step 1: Establish a connection to the Database
#
# You will need to setup the client so that it connects to your project.
#
# Then, you'll need to specify the database within this project.
#
# Finally, you'll need to specify the collection within which you wish to make the query.

# %%
import pymongo
import credentials

#connection_string = f"mongodb+srv://{credentials.username}:{credentials.password}@cluster0.d130e9a.mongodb.net/?retryWrites=true&w=majority"
connection_string = f"mongodb+srv://{credentials.username}:{credentials.password}@cluster0.lyroaya.mongodb.net/?retryWrites=true&w=majority"
client = pymongo.MongoClient(connection_string)
db = client['cardio'] # this is a 'database'
collection = db['patients'] # this is a 'collection'

# %%
print(connection_string)
# Out:
# mongodb+srv://akhilsura28:Fall2022usa@cluster0.lyroaya.mongodb.net/?retryWrites=true&w=majority

# %% [markdown]
# ## Step2: Query the collection
#
# You can use many different approaches to querrying the collection.

# %% [markdown]
# ### Get all documents in a collection

# %%
import json  
query = {} # select all documents (same as select * from patients)
doc = collection.find(query)
for record in doc: # 'doc' is a cursor that we can iterate over
    print(record)
# Out:
# {'_id': 1, 'office_num': [8], 'patient_info': {'fname': 'Jordan', 'lname': 'Smith', 'mname': 'Jane'}, 'patient_numbers': ['510-494-1528', '160-449-8315', '628-319-5148', '564-233-3413'], 'weights': [125, 153, 266, 387], 'height': 198, 'bp_readings': [{'Systolic': 102, 'Diastolic': 91, 'Rate': 74}, {'Systolic': 122, 'Diastolic': 98, 'Rate': 104}, {'Systolic': 130, 'Diastolic': 80, 'Rate': 108}, {'Systolic': 112, 'Diastolic': 83, 'Rate': 86}, {'Systolic': 126, 'Diastolic': 83, 'Rate': 80}, {'Systolic': 103, 'Diastolic': 70, 'Rate': 77}, {'Systolic': 100, 'Diastolic': 73, 'Rate': 94}, {'Systolic': 121, 'Diastolic': 79, 'Rate': 84}, {'Systolic': 135, 'Diastolic': 95, 'Rate': 87}], 'comments': 'good patient', 'readings': [{'Systolic': 999, 'Diastolic': 999, 'Rate': 999}]}
# {'_id': 2, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['528-130-0797', '253-298-7373', '898-939-6286'], 'weights': [149, 326, 153, 256, 222], 'height': 139, 'bp_readings': [{'Systolic': 135, 'Diastolic': 71, 'Rate': 82}, {'Systolic': 121, 'Diastolic': 80, 'Rate': 65}, {'Systolic': 150, 'Diastolic': 72, 'Rate': 110}, {'Systolic': 119, 'Diastolic': 74, 'Rate': 106}, {'Systolic': 125, 'Diastolic': 94, 'Rate': 75}]}
# {'_id': 3, 'office_num': [5], 'patient_info': {'fname': 'Liam', 'lname': 'Jones'}, 'patient_numbers': ['644-156-9992', '863-337-8150', '999-770-5886', '115-513-7787'], 'weights': [257, 300, 346, 358], 'height': 113, 'bp_readings': [{'Systolic': 143, 'Diastolic': 96, 'Rate': 98}, {'Systolic': 118, 'Diastolic': 87, 'Rate': 70}, {'Systolic': 131, 'Diastolic': 80, 'Rate': 100}, {'Systolic': 145, 'Diastolic': 95, 'Rate': 100}]}
# {'_id': 4, 'office_num': [6], 'patient_info': {'fname': 'Richard', 'lname': 'Hart'}, 'patient_numbers': ['120-553-4906', '284-176-5012', '493-727-1391', '270-698-7209'], 'weights': [132], 'height': 119, 'bp_readings': [{'Systolic': 129, 'Diastolic': 99, 'Rate': 107}, {'Systolic': 139, 'Diastolic': 86, 'Rate': 75}, {'Systolic': 110, 'Diastolic': 94, 'Rate': 84}, {'Systolic': 146, 'Diastolic': 99, 'Rate': 104}, {'Systolic': 103, 'Diastolic': 80, 'Rate': 81}, {'Systolic': 107, 'Diastolic': 72, 'Rate': 84}, {'Systolic': 109, 'Diastolic': 98, 'Rate': 94}]}
# {'_id': 5, 'office_num': [4], 'patient_info': {'fname': 'Jerry', 'lname': 'Boone'}, 'patient_numbers': ['049-092-0196', '134-731-0171', '473-607-5803'], 'weights': [212, 350, 269], 'height': 162, 'bp_readings': [{'Systolic': 107, 'Diastolic': 73, 'Rate': 70}, {'Systolic': 111, 'Diastolic': 78, 'Rate': 101}, {'Systolic': 123, 'Diastolic': 81, 'Rate': 85}, {'Systolic': 135, 'Diastolic': 95, 'Rate': 65}, {'Systolic': 101, 'Diastolic': 91, 'Rate': 78}, {'Systolic': 146, 'Diastolic': 82, 'Rate': 109}, {'Systolic': 120, 'Diastolic': 96, 'Rate': 72}, {'Systolic': 142, 'Diastolic': 94, 'Rate': 87}, {'Systolic': 130, 'Diastolic': 80, 'Rate': 100}]}
# {'_id': 6, 'office_num': [2], 'patient_info': {'fname': 'Richard', 'lname': 'Madden'}, 'patient_numbers': ['100-716-2428', '201-785-9853'], 'weights': [234, 275, 308, 207, 375], 'height': 135, 'bp_readings': [{'Systolic': 114, 'Diastolic': 92, 'Rate': 110}, {'Systolic': 129, 'Diastolic': 84, 'Rate': 94}, {'Systolic': 127, 'Diastolic': 94, 'Rate': 84}, {'Systolic': 107, 'Diastolic': 77, 'Rate': 75}]}
# {'_id': 7, 'office_num': [8], 'patient_info': {'fname': 'Liam', 'lname': ' Fox'}, 'patient_numbers': ['653-684-7515', '045-819-7256'], 'weights': [98, 180, 162, 379, 266], 'height': 135, 'bp_readings': [{'Systolic': 125, 'Diastolic': 85, 'Rate': 63}, {'Systolic': 144, 'Diastolic': 71, 'Rate': 97}, {'Systolic': 150, 'Diastolic': 74, 'Rate': 108}, {'Systolic': 126, 'Diastolic': 95, 'Rate': 101}, {'Systolic': 134, 'Diastolic': 84, 'Rate': 79}, {'Systolic': 114, 'Diastolic': 81, 'Rate': 95}, {'Systolic': 104, 'Diastolic': 74, 'Rate': 103}, {'Systolic': 137, 'Diastolic': 94, 'Rate': 109}, {'Systolic': 112, 'Diastolic': 79, 'Rate': 61}, {'Systolic': 135, 'Diastolic': 77, 'Rate': 88}]}
# {'_id': 8, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Boone'}, 'patient_numbers': ['118-146-4696', '853-751-9706', '631-269-6143', '128-218-4240'], 'weights': [193, 385, 194, 160, 196], 'height': 189, 'bp_readings': [{'Systolic': 142, 'Diastolic': 78, 'Rate': 93}, {'Systolic': 101, 'Diastolic': 76, 'Rate': 73}, {'Systolic': 140, 'Diastolic': 87, 'Rate': 107}, {'Systolic': 140, 'Diastolic': 83, 'Rate': 70}, {'Systolic': 149, 'Diastolic': 89, 'Rate': 92}, {'Systolic': 103, 'Diastolic': 95, 'Rate': 75}, {'Systolic': 128, 'Diastolic': 80, 'Rate': 88}, {'Systolic': 111, 'Diastolic': 90, 'Rate': 95}]}
# {'_id': 9, 'office_num': [5], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['893-421-2922', '786-231-9620', '501-218-5126'], 'weights': [373, 194, 203, 292, 95], 'height': 138, 'bp_readings': [{'Systolic': 123, 'Diastolic': 89, 'Rate': 60}, {'Systolic': 150, 'Diastolic': 74, 'Rate': 108}, {'Systolic': 119, 'Diastolic': 84, 'Rate': 93}, {'Systolic': 143, 'Diastolic': 85, 'Rate': 87}, {'Systolic': 104, 'Diastolic': 92, 'Rate': 79}, {'Systolic': 109, 'Diastolic': 97, 'Rate': 93}, {'Systolic': 119, 'Diastolic': 81, 'Rate': 64}, {'Systolic': 139, 'Diastolic': 87, 'Rate': 95}, {'Systolic': 150, 'Diastolic': 84, 'Rate': 83}, {'Systolic': 137, 'Diastolic': 71, 'Rate': 88}]}
# {'_id': 10, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Granger'}, 'patient_numbers': ['914-270-1796', '007-332-2036', '727-933-2066', '181-475-8629'], 'weights': [178, 111, 240, 254], 'height': 166, 'bp_readings': [{'Systolic': 101, 'Diastolic': 80, 'Rate': 86}, {'Systolic': 110, 'Diastolic': 88, 'Rate': 85}, {'Systolic': 136, 'Diastolic': 82, 'Rate': 67}, {'Systolic': 115, 'Diastolic': 94, 'Rate': 61}, {'Systolic': 115, 'Diastolic': 89, 'Rate': 73}, {'Systolic': 138, 'Diastolic': 97, 'Rate': 61}, {'Systolic': 107, 'Diastolic': 98, 'Rate': 95}, {'Systolic': 135, 'Diastolic': 72, 'Rate': 97}, {'Systolic': 123, 'Diastolic': 98, 'Rate': 79}]}
# {'_id': 11, 'office_num': [9], 'patient_info': {'fname': 'Richard', 'lname': 'Boone'}, 'patient_numbers': ['127-046-8212', '659-052-2244', '839-910-6764'], 'weights': [101, 392, 355, 261], 'height': 116, 'bp_readings': [{'Systolic': 132, 'Diastolic': 92, 'Rate': 67}, {'Systolic': 100, 'Diastolic': 85, 'Rate': 66}, {'Systolic': 146, 'Diastolic': 85, 'Rate': 77}, {'Systolic': 111, 'Diastolic': 81, 'Rate': 63}, {'Systolic': 100, 'Diastolic': 71, 'Rate': 96}, {'Systolic': 100, 'Diastolic': 89, 'Rate': 110}]}
# {'_id': 12, 'office_num': [1], 'patient_info': {'fname': 'Jordan', 'lname': 'Madden'}, 'patient_numbers': ['545-438-3955', '837-914-3989'], 'weights': [160, 388, 154, 312, 286], 'height': 129, 'bp_readings': [{'Systolic': 110, 'Diastolic': 90, 'Rate': 88}, {'Systolic': 150, 'Diastolic': 88, 'Rate': 74}, {'Systolic': 138, 'Diastolic': 97, 'Rate': 109}, {'Systolic': 128, 'Diastolic': 78, 'Rate': 76}, {'Systolic': 139, 'Diastolic': 96, 'Rate': 77}]}
# {'_id': 13, 'office_num': [6], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['713-176-8049', '496-331-4552', '137-364-7076', '051-030-8369'], 'weights': [291, 177], 'height': 154, 'bp_readings': [{'Systolic': 122, 'Diastolic': 75, 'Rate': 92}, {'Systolic': 104, 'Diastolic': 81, 'Rate': 100}, {'Systolic': 122, 'Diastolic': 71, 'Rate': 78}, {'Systolic': 141, 'Diastolic': 82, 'Rate': 98}]}
# {'_id': 14, 'office_num': [10], 'patient_info': {'fname': 'Ethan', 'lname': 'Madden'}, 'patient_numbers': ['363-965-0725', '344-924-2642'], 'weights': [98, 196, 384], 'height': 190, 'bp_readings': [{'Systolic': 119, 'Diastolic': 88, 'Rate': 109}, {'Systolic': 106, 'Diastolic': 84, 'Rate': 100}, {'Systolic': 104, 'Diastolic': 89, 'Rate': 93}, {'Systolic': 108, 'Diastolic': 94, 'Rate': 74}, {'Systolic': 128, 'Diastolic': 98, 'Rate': 79}]}
# {'_id': 15, 'office_num': [6], 'patient_info': {'fname': 'Jerry', 'lname': 'Hart'}, 'patient_numbers': ['492-609-7919', '552-344-7173', '381-139-4744'], 'weights': [359, 137, 215], 'height': 155, 'bp_readings': [{'Systolic': 149, 'Diastolic': 90, 'Rate': 106}, {'Systolic': 137, 'Diastolic': 93, 'Rate': 109}, {'Systolic': 113, 'Diastolic': 73, 'Rate': 87}, {'Systolic': 101, 'Diastolic': 70, 'Rate': 84}, {'Systolic': 113, 'Diastolic': 85, 'Rate': 78}, {'Systolic': 143, 'Diastolic': 93, 'Rate': 102}, {'Systolic': 125, 'Diastolic': 74, 'Rate': 74}, {'Systolic': 116, 'Diastolic': 72, 'Rate': 109}, {'Systolic': 130, 'Diastolic': 77, 'Rate': 63}, {'Systolic': 146, 'Diastolic': 89, 'Rate': 74}]}
# {'_id': 16, 'office_num': [1], 'patient_info': {'fname': 'Jordan', 'lname': 'Hale'}, 'patient_numbers': ['154-090-3578', '670-064-8514', '014-666-6302'], 'weights': [202, 272, 116], 'height': 137, 'bp_readings': [{'Systolic': 141, 'Diastolic': 80, 'Rate': 104}, {'Systolic': 125, 'Diastolic': 95, 'Rate': 82}, {'Systolic': 105, 'Diastolic': 84, 'Rate': 99}, {'Systolic': 124, 'Diastolic': 70, 'Rate': 65}, {'Systolic': 131, 'Diastolic': 77, 'Rate': 60}, {'Systolic': 122, 'Diastolic': 79, 'Rate': 67}, {'Systolic': 101, 'Diastolic': 74, 'Rate': 92}, {'Systolic': 114, 'Diastolic': 80, 'Rate': 101}, {'Systolic': 126, 'Diastolic': 87, 'Rate': 78}]}
# {'_id': 17, 'office_num': [4], 'patient_info': {'fname': 'Betty', 'lname': ' Fox'}, 'patient_numbers': ['369-778-4121', '014-192-8069', '129-610-7272', '744-317-8177'], 'weights': [224, 121], 'height': 186, 'bp_readings': [{'Systolic': 108, 'Diastolic': 94, 'Rate': 94}, {'Systolic': 115, 'Diastolic': 96, 'Rate': 89}, {'Systolic': 102, 'Diastolic': 73, 'Rate': 85}, {'Systolic': 143, 'Diastolic': 78, 'Rate': 100}, {'Systolic': 117, 'Diastolic': 98, 'Rate': 64}, {'Systolic': 100, 'Diastolic': 84, 'Rate': 97}]}
# {'_id': 18, 'office_num': [10], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Madden'}, 'patient_numbers': ['765-638-7096', '087-933-0702', '421-382-2477'], 'weights': [132], 'height': 153, 'bp_readings': [{'Systolic': 142, 'Diastolic': 79, 'Rate': 103}, {'Systolic': 149, 'Diastolic': 81, 'Rate': 79}, {'Systolic': 101, 'Diastolic': 70, 'Rate': 64}]}
# {'_id': 19, 'office_num': [1], 'patient_info': {'fname': 'Ethan', 'lname': 'Madden'}, 'patient_numbers': ['481-987-8882', '374-886-6907', '489-291-4617'], 'weights': [368, 295, 115], 'height': 135, 'bp_readings': [{'Systolic': 111, 'Diastolic': 73, 'Rate': 108}, {'Systolic': 117, 'Diastolic': 88, 'Rate': 81}, {'Systolic': 107, 'Diastolic': 82, 'Rate': 62}, {'Systolic': 118, 'Diastolic': 87, 'Rate': 65}]}
# {'_id': 20, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['972-440-9434', '082-472-6661', '519-292-3029', '483-712-8004'], 'weights': [260], 'height': 186, 'bp_readings': [{'Systolic': 117, 'Diastolic': 84, 'Rate': 98}, {'Systolic': 102, 'Diastolic': 70, 'Rate': 88}, {'Systolic': 139, 'Diastolic': 86, 'Rate': 99}, {'Systolic': 110, 'Diastolic': 81, 'Rate': 95}, {'Systolic': 147, 'Diastolic': 87, 'Rate': 65}, {'Systolic': 143, 'Diastolic': 82, 'Rate': 102}, {'Systolic': 129, 'Diastolic': 98, 'Rate': 90}]}
# {'_id': 21, 'office_num': [2], 'patient_info': {'fname': 'Liam', 'lname': 'Boone'}, 'patient_numbers': ['116-438-2583', '510-457-3871'], 'weights': [369, 256, 339, 309], 'height': 110, 'bp_readings': [{'Systolic': 144, 'Diastolic': 96, 'Rate': 95}, {'Systolic': 108, 'Diastolic': 91, 'Rate': 84}]}
# {'_id': 22, 'office_num': [7], 'patient_info': {'fname': 'Susan', 'lname': 'Hart'}, 'patient_numbers': ['980-365-7411', '026-674-4727', '488-419-7640', '771-907-9718'], 'weights': [120], 'height': 108, 'bp_readings': [{'Systolic': 127, 'Diastolic': 92, 'Rate': 107}, {'Systolic': 132, 'Diastolic': 81, 'Rate': 97}, {'Systolic': 126, 'Diastolic': 71, 'Rate': 71}, {'Systolic': 124, 'Diastolic': 84, 'Rate': 110}]}
# {'_id': 23, 'office_num': [6], 'patient_info': {'fname': 'Tom', 'lname': 'Madden'}, 'patient_numbers': ['514-790-2184', '021-408-6710', '587-589-3021'], 'weights': [316, 103, 304], 'height': 126, 'bp_readings': [{'Systolic': 128, 'Diastolic': 79, 'Rate': 94}, {'Systolic': 106, 'Diastolic': 85, 'Rate': 85}, {'Systolic': 127, 'Diastolic': 79, 'Rate': 81}, {'Systolic': 140, 'Diastolic': 95, 'Rate': 96}, {'Systolic': 114, 'Diastolic': 93, 'Rate': 106}, {'Systolic': 109, 'Diastolic': 85, 'Rate': 70}, {'Systolic': 117, 'Diastolic': 80, 'Rate': 80}, {'Systolic': 119, 'Diastolic': 90, 'Rate': 83}, {'Systolic': 125, 'Diastolic': 98, 'Rate': 98}, {'Systolic': 126, 'Diastolic': 94, 'Rate': 73}]}
# {'_id': 24, 'office_num': [4], 'patient_info': {'fname': 'Jerry', 'lname': 'Carmichael'}, 'patient_numbers': ['027-509-9403', '619-112-6697', '988-733-4099'], 'weights': [198, 220, 360], 'height': 110, 'bp_readings': [{'Systolic': 106, 'Diastolic': 99, 'Rate': 105}, {'Systolic': 115, 'Diastolic': 94, 'Rate': 86}]}
# {'_id': 25, 'office_num': [6], 'patient_info': {'fname': 'Jack', 'lname': 'Smith'}, 'patient_numbers': ['308-994-0395', '918-832-0218', '048-908-1600'], 'weights': [183], 'height': 146, 'bp_readings': [{'Systolic': 120, 'Diastolic': 71, 'Rate': 105}, {'Systolic': 126, 'Diastolic': 94, 'Rate': 101}, {'Systolic': 116, 'Diastolic': 84, 'Rate': 99}, {'Systolic': 143, 'Diastolic': 99, 'Rate': 97}, {'Systolic': 140, 'Diastolic': 90, 'Rate': 84}, {'Systolic': 136, 'Diastolic': 99, 'Rate': 68}, {'Systolic': 107, 'Diastolic': 93, 'Rate': 93}, {'Systolic': 124, 'Diastolic': 79, 'Rate': 67}]}
# {'_id': 26, 'office_num': [4], 'patient_info': {'fname': 'Betty', 'lname': 'Hale'}, 'patient_numbers': ['710-170-1715', '347-757-6450', '458-243-1366'], 'weights': [294, 380, 162, 337, 250], 'height': 144, 'bp_readings': [{'Systolic': 109, 'Diastolic': 95, 'Rate': 95}, {'Systolic': 109, 'Diastolic': 76, 'Rate': 83}, {'Systolic': 105, 'Diastolic': 84, 'Rate': 81}, {'Systolic': 114, 'Diastolic': 97, 'Rate': 82}, {'Systolic': 136, 'Diastolic': 97, 'Rate': 88}]}
# {'_id': 27, 'office_num': [9], 'patient_info': {'fname': 'Liam', 'lname': 'Smith'}, 'patient_numbers': ['358-885-6398', '296-386-9448', '846-186-4133', '113-735-7625'], 'weights': [96, 257, 95], 'height': 177, 'bp_readings': [{'Systolic': 109, 'Diastolic': 79, 'Rate': 102}, {'Systolic': 125, 'Diastolic': 71, 'Rate': 88}, {'Systolic': 129, 'Diastolic': 82, 'Rate': 70}, {'Systolic': 122, 'Diastolic': 92, 'Rate': 103}, {'Systolic': 114, 'Diastolic': 97, 'Rate': 105}, {'Systolic': 135, 'Diastolic': 81, 'Rate': 81}, {'Systolic': 103, 'Diastolic': 99, 'Rate': 100}, {'Systolic': 105, 'Diastolic': 71, 'Rate': 60}, {'Systolic': 147, 'Diastolic': 78, 'Rate': 64}]}
# {'_id': 28, 'office_num': [4], 'patient_info': {'fname': 'Susan', 'lname': ' Fox'}, 'patient_numbers': ['651-740-4519', '004-323-0319'], 'weights': [200, 196], 'height': 124, 'bp_readings': [{'Systolic': 118, 'Diastolic': 79, 'Rate': 74}, {'Systolic': 126, 'Diastolic': 89, 'Rate': 82}, {'Systolic': 137, 'Diastolic': 76, 'Rate': 88}]}
# {'_id': 29, 'office_num': [2], 'patient_info': {'fname': 'Liam', 'lname': 'Boone'}, 'patient_numbers': ['068-555-9335', '962-181-5644'], 'weights': [163, 379, 280, 91, 273], 'height': 145, 'bp_readings': [{'Systolic': 126, 'Diastolic': 92, 'Rate': 107}, {'Systolic': 149, 'Diastolic': 88, 'Rate': 110}, {'Systolic': 141, 'Diastolic': 99, 'Rate': 92}, {'Systolic': 142, 'Diastolic': 96, 'Rate': 61}, {'Systolic': 126, 'Diastolic': 78, 'Rate': 98}, {'Systolic': 103, 'Diastolic': 79, 'Rate': 100}, {'Systolic': 148, 'Diastolic': 74, 'Rate': 75}]}
# {'_id': 30, 'office_num': [3], 'patient_info': {'fname': 'Jack', 'lname': 'Langston'}, 'patient_numbers': ['394-907-9040', '584-742-0182', '652-925-6579'], 'weights': [325, 270], 'height': 191, 'bp_readings': [{'Systolic': 113, 'Diastolic': 77, 'Rate': 104}, {'Systolic': 126, 'Diastolic': 86, 'Rate': 94}, {'Systolic': 123, 'Diastolic': 90, 'Rate': 74}, {'Systolic': 117, 'Diastolic': 91, 'Rate': 81}, {'Systolic': 140, 'Diastolic': 98, 'Rate': 106}, {'Systolic': 150, 'Diastolic': 73, 'Rate': 69}, {'Systolic': 112, 'Diastolic': 70, 'Rate': 73}, {'Systolic': 131, 'Diastolic': 87, 'Rate': 80}, {'Systolic': 110, 'Diastolic': 95, 'Rate': 61}]}
# {'_id': 31, 'office_num': [5], 'patient_info': {'fname': 'Ethan', 'lname': 'Hale'}, 'patient_numbers': ['411-975-1214', '438-433-2826'], 'weights': [334, 198, 104, 194], 'height': 172, 'bp_readings': [{'Systolic': 142, 'Diastolic': 93, 'Rate': 110}, {'Systolic': 144, 'Diastolic': 99, 'Rate': 107}, {'Systolic': 143, 'Diastolic': 72, 'Rate': 93}, {'Systolic': 107, 'Diastolic': 84, 'Rate': 70}, {'Systolic': 100, 'Diastolic': 96, 'Rate': 97}, {'Systolic': 145, 'Diastolic': 78, 'Rate': 90}, {'Systolic': 113, 'Diastolic': 94, 'Rate': 109}, {'Systolic': 133, 'Diastolic': 89, 'Rate': 103}, {'Systolic': 126, 'Diastolic': 98, 'Rate': 63}, {'Systolic': 131, 'Diastolic': 70, 'Rate': 108}]}
# {'_id': 32, 'office_num': [3], 'patient_info': {'fname': 'Tom', 'lname': 'Hart'}, 'patient_numbers': ['134-212-3252', '596-871-2312', '171-337-7720'], 'weights': [378, 231, 102, 309, 358], 'height': 147, 'bp_readings': [{'Systolic': 126, 'Diastolic': 84, 'Rate': 68}, {'Systolic': 118, 'Diastolic': 76, 'Rate': 77}, {'Systolic': 149, 'Diastolic': 76, 'Rate': 73}, {'Systolic': 100, 'Diastolic': 89, 'Rate': 103}, {'Systolic': 116, 'Diastolic': 81, 'Rate': 67}]}
# {'_id': 33, 'office_num': [1], 'patient_info': {'fname': 'Richard', 'lname': 'Jones'}, 'patient_numbers': ['622-740-2217', '895-898-7674', '159-362-8489', '667-242-9724'], 'weights': [380, 197, 161, 283, 382], 'height': 116, 'bp_readings': [{'Systolic': 102, 'Diastolic': 79, 'Rate': 80}, {'Systolic': 131, 'Diastolic': 97, 'Rate': 105}, {'Systolic': 147, 'Diastolic': 86, 'Rate': 80}, {'Systolic': 138, 'Diastolic': 89, 'Rate': 109}, {'Systolic': 113, 'Diastolic': 94, 'Rate': 67}, {'Systolic': 101, 'Diastolic': 84, 'Rate': 106}, {'Systolic': 100, 'Diastolic': 90, 'Rate': 73}, {'Systolic': 104, 'Diastolic': 73, 'Rate': 72}, {'Systolic': 119, 'Diastolic': 94, 'Rate': 102}, {'Systolic': 127, 'Diastolic': 79, 'Rate': 81}]}
# {'_id': 34, 'office_num': [1], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['250-489-8136', '209-189-7571'], 'weights': [254, 216, 296], 'height': 177, 'bp_readings': [{'Systolic': 144, 'Diastolic': 91, 'Rate': 89}, {'Systolic': 124, 'Diastolic': 87, 'Rate': 108}, {'Systolic': 101, 'Diastolic': 74, 'Rate': 78}, {'Systolic': 136, 'Diastolic': 94, 'Rate': 67}, {'Systolic': 100, 'Diastolic': 73, 'Rate': 109}, {'Systolic': 128, 'Diastolic': 99, 'Rate': 89}, {'Systolic': 148, 'Diastolic': 77, 'Rate': 80}, {'Systolic': 140, 'Diastolic': 75, 'Rate': 77}, {'Systolic': 135, 'Diastolic': 85, 'Rate': 75}, {'Systolic': 124, 'Diastolic': 71, 'Rate': 94}]}
# {'_id': 35, 'office_num': [9], 'patient_info': {'fname': 'Jerry', 'lname': 'Langston'}, 'patient_numbers': ['631-443-6485', '227-670-5130', '593-269-5740'], 'weights': [168, 286, 354, 319], 'height': 106, 'bp_readings': [{'Systolic': 103, 'Diastolic': 84, 'Rate': 100}, {'Systolic': 129, 'Diastolic': 91, 'Rate': 94}, {'Systolic': 143, 'Diastolic': 78, 'Rate': 91}, {'Systolic': 118, 'Diastolic': 77, 'Rate': 80}, {'Systolic': 108, 'Diastolic': 96, 'Rate': 89}, {'Systolic': 108, 'Diastolic': 89, 'Rate': 73}, {'Systolic': 132, 'Diastolic': 83, 'Rate': 60}]}
# {'_id': 36, 'office_num': [9], 'patient_info': {'fname': 'James', 'lname': 'Hale'}, 'patient_numbers': ['636-870-5319', '895-034-1896', '543-304-8986', '848-344-1469'], 'weights': [141, 319, 353, 266], 'height': 184, 'bp_readings': [{'Systolic': 101, 'Diastolic': 76, 'Rate': 84}, {'Systolic': 109, 'Diastolic': 73, 'Rate': 100}, {'Systolic': 113, 'Diastolic': 92, 'Rate': 95}, {'Systolic': 136, 'Diastolic': 81, 'Rate': 89}, {'Systolic': 132, 'Diastolic': 90, 'Rate': 84}, {'Systolic': 148, 'Diastolic': 76, 'Rate': 91}, {'Systolic': 134, 'Diastolic': 94, 'Rate': 82}, {'Systolic': 142, 'Diastolic': 93, 'Rate': 102}]}
# {'_id': 37, 'office_num': [1], 'patient_info': {'fname': 'Liam', 'lname': ' Fox'}, 'patient_numbers': ['378-533-7858', '537-754-1935', '819-478-5505', '180-802-2297'], 'weights': [256, 223, 372], 'height': 106, 'bp_readings': [{'Systolic': 100, 'Diastolic': 87, 'Rate': 93}, {'Systolic': 146, 'Diastolic': 73, 'Rate': 75}, {'Systolic': 137, 'Diastolic': 84, 'Rate': 81}, {'Systolic': 128, 'Diastolic': 81, 'Rate': 81}]}
# {'_id': 38, 'office_num': [9], 'patient_info': {'fname': 'Jack', 'lname': 'Granger'}, 'patient_numbers': ['888-114-1026', '625-676-9429', '903-783-1338'], 'weights': [398, 331, 130], 'height': 155, 'bp_readings': [{'Systolic': 130, 'Diastolic': 79, 'Rate': 79}, {'Systolic': 123, 'Diastolic': 99, 'Rate': 108}, {'Systolic': 107, 'Diastolic': 98, 'Rate': 89}, {'Systolic': 109, 'Diastolic': 95, 'Rate': 105}, {'Systolic': 120, 'Diastolic': 84, 'Rate': 91}, {'Systolic': 143, 'Diastolic': 85, 'Rate': 61}]}
# {'_id': 39, 'office_num': [9], 'patient_info': {'fname': 'Susan', 'lname': 'Smith'}, 'patient_numbers': ['227-869-3656', '410-846-3569'], 'weights': [169, 92, 172, 212], 'height': 121, 'bp_readings': [{'Systolic': 128, 'Diastolic': 74, 'Rate': 63}, {'Systolic': 145, 'Diastolic': 98, 'Rate': 68}, {'Systolic': 115, 'Diastolic': 98, 'Rate': 105}, {'Systolic': 137, 'Diastolic': 72, 'Rate': 89}, {'Systolic': 138, 'Diastolic': 82, 'Rate': 101}, {'Systolic': 139, 'Diastolic': 85, 'Rate': 73}, {'Systolic': 135, 'Diastolic': 92, 'Rate': 85}, {'Systolic': 129, 'Diastolic': 74, 'Rate': 66}]}
# {'_id': 40, 'office_num': [2], 'patient_info': {'fname': 'Jack', 'lname': 'Jones'}, 'patient_numbers': ['040-254-9970', '035-280-9701', '840-678-2039', '757-744-7500'], 'weights': [337, 119], 'height': 105, 'bp_readings': [{'Systolic': 118, 'Diastolic': 89, 'Rate': 90}, {'Systolic': 142, 'Diastolic': 81, 'Rate': 79}, {'Systolic': 110, 'Diastolic': 88, 'Rate': 69}, {'Systolic': 136, 'Diastolic': 97, 'Rate': 63}, {'Systolic': 130, 'Diastolic': 71, 'Rate': 107}, {'Systolic': 130, 'Diastolic': 71, 'Rate': 101}, {'Systolic': 135, 'Diastolic': 76, 'Rate': 65}, {'Systolic': 100, 'Diastolic': 96, 'Rate': 102}]}
# {'_id': 41, 'office_num': [4], 'patient_info': {'fname': 'Richard', 'lname': 'Hart'}, 'patient_numbers': ['456-669-4613', '630-135-0952'], 'weights': [313], 'height': 120, 'bp_readings': [{'Systolic': 110, 'Diastolic': 75, 'Rate': 96}, {'Systolic': 108, 'Diastolic': 78, 'Rate': 102}, {'Systolic': 113, 'Diastolic': 94, 'Rate': 109}, {'Systolic': 147, 'Diastolic': 76, 'Rate': 63}, {'Systolic': 120, 'Diastolic': 75, 'Rate': 81}, {'Systolic': 131, 'Diastolic': 93, 'Rate': 91}, {'Systolic': 104, 'Diastolic': 74, 'Rate': 90}, {'Systolic': 149, 'Diastolic': 88, 'Rate': 105}]}
# {'_id': 42, 'office_num': [10], 'patient_info': {'fname': 'Liam', 'lname': 'Smith'}, 'patient_numbers': ['855-871-4130', '931-621-4641'], 'weights': [96, 132], 'height': 165, 'bp_readings': [{'Systolic': 124, 'Diastolic': 79, 'Rate': 98}, {'Systolic': 147, 'Diastolic': 89, 'Rate': 62}, {'Systolic': 127, 'Diastolic': 99, 'Rate': 89}, {'Systolic': 104, 'Diastolic': 80, 'Rate': 86}, {'Systolic': 146, 'Diastolic': 75, 'Rate': 83}]}
# {'_id': 43, 'office_num': [2], 'patient_info': {'fname': 'Susan', 'lname': ' Fox'}, 'patient_numbers': ['090-196-5242', '407-722-8626'], 'weights': [373, 100, 398, 338], 'height': 130, 'bp_readings': [{'Systolic': 115, 'Diastolic': 72, 'Rate': 64}, {'Systolic': 111, 'Diastolic': 84, 'Rate': 61}, {'Systolic': 108, 'Diastolic': 85, 'Rate': 105}, {'Systolic': 121, 'Diastolic': 95, 'Rate': 97}, {'Systolic': 147, 'Diastolic': 71, 'Rate': 63}, {'Systolic': 117, 'Diastolic': 96, 'Rate': 61}, {'Systolic': 117, 'Diastolic': 74, 'Rate': 63}, {'Systolic': 134, 'Diastolic': 96, 'Rate': 100}, {'Systolic': 120, 'Diastolic': 91, 'Rate': 105}, {'Systolic': 138, 'Diastolic': 72, 'Rate': 74}]}
# {'_id': 44, 'office_num': [3], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['997-540-6376', '570-769-9027', '774-466-1209'], 'weights': [309], 'height': 172, 'bp_readings': [{'Systolic': 137, 'Diastolic': 89, 'Rate': 88}, {'Systolic': 104, 'Diastolic': 75, 'Rate': 95}, {'Systolic': 130, 'Diastolic': 82, 'Rate': 71}, {'Systolic': 128, 'Diastolic': 98, 'Rate': 88}, {'Systolic': 137, 'Diastolic': 73, 'Rate': 81}, {'Systolic': 120, 'Diastolic': 91, 'Rate': 61}, {'Systolic': 145, 'Diastolic': 70, 'Rate': 109}, {'Systolic': 103, 'Diastolic': 74, 'Rate': 63}, {'Systolic': 113, 'Diastolic': 83, 'Rate': 74}, {'Systolic': 132, 'Diastolic': 96, 'Rate': 108}]}
# {'_id': 45, 'office_num': [9], 'patient_info': {'fname': 'James', 'lname': 'Langston'}, 'patient_numbers': ['210-570-9775', '130-469-7826'], 'weights': [242, 154, 227, 285], 'height': 160, 'bp_readings': [{'Systolic': 144, 'Diastolic': 82, 'Rate': 97}, {'Systolic': 119, 'Diastolic': 77, 'Rate': 110}]}
# {'_id': 46, 'office_num': [3], 'patient_info': {'fname': 'Betty', 'lname': 'Madden'}, 'patient_numbers': ['465-521-6381', '396-414-4523', '914-527-0689', '884-089-7413'], 'weights': [388, 227, 174, 389], 'height': 127, 'bp_readings': [{'Systolic': 138, 'Diastolic': 90, 'Rate': 92}, {'Systolic': 132, 'Diastolic': 84, 'Rate': 92}, {'Systolic': 121, 'Diastolic': 98, 'Rate': 65}, {'Systolic': 124, 'Diastolic': 98, 'Rate': 102}, {'Systolic': 117, 'Diastolic': 78, 'Rate': 63}, {'Systolic': 139, 'Diastolic': 86, 'Rate': 86}, {'Systolic': 135, 'Diastolic': 98, 'Rate': 106}, {'Systolic': 105, 'Diastolic': 93, 'Rate': 66}, {'Systolic': 144, 'Diastolic': 89, 'Rate': 66}]}
# {'_id': 47, 'office_num': [7], 'patient_info': {'fname': 'Betty', 'lname': 'Jones'}, 'patient_numbers': ['507-610-3989', '115-430-8233', '225-908-6038'], 'weights': [224], 'height': 156, 'bp_readings': [{'Systolic': 114, 'Diastolic': 78, 'Rate': 95}, {'Systolic': 144, 'Diastolic': 79, 'Rate': 62}, {'Systolic': 141, 'Diastolic': 89, 'Rate': 96}, {'Systolic': 114, 'Diastolic': 83, 'Rate': 77}, {'Systolic': 128, 'Diastolic': 85, 'Rate': 90}, {'Systolic': 127, 'Diastolic': 80, 'Rate': 63}, {'Systolic': 138, 'Diastolic': 85, 'Rate': 105}]}
# {'_id': 48, 'office_num': [9], 'patient_info': {'fname': 'Betty', 'lname': 'Jones'}, 'patient_numbers': ['974-983-8821', '042-974-9089'], 'weights': [205, 355, 173, 316, 357], 'height': 149, 'bp_readings': [{'Systolic': 131, 'Diastolic': 73, 'Rate': 107}, {'Systolic': 113, 'Diastolic': 85, 'Rate': 101}, {'Systolic': 100, 'Diastolic': 76, 'Rate': 110}, {'Systolic': 111, 'Diastolic': 77, 'Rate': 69}, {'Systolic': 123, 'Diastolic': 83, 'Rate': 99}, {'Systolic': 109, 'Diastolic': 71, 'Rate': 76}, {'Systolic': 119, 'Diastolic': 78, 'Rate': 83}, {'Systolic': 107, 'Diastolic': 77, 'Rate': 64}, {'Systolic': 126, 'Diastolic': 84, 'Rate': 65}]}
# {'_id': 49, 'office_num': [2], 'patient_info': {'fname': 'Betty', 'lname': 'Smith'}, 'patient_numbers': ['552-529-6576', '546-675-3594', '895-723-5862', '472-705-2764'], 'weights': [365], 'height': 142, 'bp_readings': [{'Systolic': 150, 'Diastolic': 97, 'Rate': 66}, {'Systolic': 131, 'Diastolic': 78, 'Rate': 105}, {'Systolic': 128, 'Diastolic': 82, 'Rate': 86}, {'Systolic': 132, 'Diastolic': 73, 'Rate': 66}]}

# %% [markdown]
# ### Find a document based on a (first level) field value

# %%
query = { "_id": 1 } # search for any five start restaurants
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4)) # using json.dumps() to make the output more readable
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "510-494-1528",
#         "160-449-8315",
#         "628-319-5148",
#         "564-233-3413"
#     ],
#     "weights": [
#         125,
#         153,
#         266,
#         387
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 91,
#             "Rate": 74
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 98,
#             "Rate": 104
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 80,
#             "Rate": 108
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 86
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 83,
#             "Rate": 80
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 70,
#             "Rate": 77
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 73,
#             "Rate": 94
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 79,
#             "Rate": 84
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 95,
#             "Rate": 87
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": "good patient" }
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "510-494-1528",
#         "160-449-8315",
#         "628-319-5148",
#         "564-233-3413"
#     ],
#     "weights": [
#         125,
#         153,
#         266,
#         387
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 91,
#             "Rate": 74
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 98,
#             "Rate": 104
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 80,
#             "Rate": 108
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 86
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 83,
#             "Rate": 80
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 70,
#             "Rate": 77
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 73,
#             "Rate": 94
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 79,
#             "Rate": 84
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 95,
#             "Rate": 87
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": {"$regex": "ood" }} # https://en.wikipedia.org/wiki/Regular_expression
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "510-494-1528",
#         "160-449-8315",
#         "628-319-5148",
#         "564-233-3413"
#     ],
#     "weights": [
#         125,
#         153,
#         266,
#         387
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 91,
#             "Rate": 74
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 98,
#             "Rate": 104
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 80,
#             "Rate": 108
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 86
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 83,
#             "Rate": 80
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 70,
#             "Rate": 77
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 73,
#             "Rate": 94
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 79,
#             "Rate": 84
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 95,
#             "Rate": 87
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Query values in an embedded array
# In our sample data, we have an embedded array of phone numbers. Here's how we can search an embedded array.

# %%
query = { "patient_numbers": {"$regex": '^160'}} # search for records that have this area code
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "510-494-1528",
#         "160-449-8315",
#         "628-319-5148",
#         "564-233-3413"
#     ],
#     "weights": [
#         125,
#         153,
#         266,
#         387
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 91,
#             "Rate": 74
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 98,
#             "Rate": 104
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 80,
#             "Rate": 108
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 86
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 83,
#             "Rate": 80
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 70,
#             "Rate": 77
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 73,
#             "Rate": 94
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 79,
#             "Rate": 84
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 95,
#             "Rate": 87
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "bp_readings": {"Systolic" : 130 , "Diastolic": 80, "Rate": 108}} # in this style, you need all fields
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "510-494-1528",
#         "160-449-8315",
#         "628-319-5148",
#         "564-233-3413"
#     ],
#     "weights": [
#         125,
#         153,
#         266,
#         387
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 91,
#             "Rate": 74
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 98,
#             "Rate": 104
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 80,
#             "Rate": 108
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 86
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 83,
#             "Rate": 80
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 70,
#             "Rate": 77
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 73,
#             "Rate": 94
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 79,
#             "Rate": 84
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 95,
#             "Rate": 87
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Querying embedded documents
#
# In our sample data, the readings field contains an array of embeded documents. Let's explore some examples showing how we can search an embedded document.

# %%
# in this style, you need all fields - so this one won't return anything
query = { "bp_readings": {"Systolic" : 104}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))

# %%
# If you want to query on one field, you can use the following approach
query = { "bp_readings.Systolic" : 142} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 5,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "049-092-0196",
#         "134-731-0171",
#         "473-607-5803"
#     ],
#     "weights": [
#         212,
#         350,
#         269
#     ],
#     "height": 162,
#     "bp_readings": [
#         {
#             "Systolic": 107,
#             "Diastolic": 73,
#             "Rate": 70
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 78,
#             "Rate": 101
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 81,
#             "Rate": 85
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 95,
#             "Rate": 65
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 91,
#             "Rate": 78
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 82,
#             "Rate": 109
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 96,
#             "Rate": 72
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 94,
#             "Rate": 87
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 80,
#             "Rate": 100
#         }
#     ]
# }
# {
#     "_id": 8,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "118-146-4696",
#         "853-751-9706",
#         "631-269-6143",
#         "128-218-4240"
#     ],
#     "weights": [
#         193,
#         385,
#         194,
#         160,
#         196
#     ],
#     "height": 189,
#     "bp_readings": [
#         {
#             "Systolic": 142,
#             "Diastolic": 78,
#             "Rate": 93
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 76,
#             "Rate": 73
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 87,
#             "Rate": 107
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 83,
#             "Rate": 70
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 89,
#             "Rate": 92
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 95,
#             "Rate": 75
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 80,
#             "Rate": 88
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 90,
#             "Rate": 95
#         }
#     ]
# }
# {
#     "_id": 18,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "765-638-7096",
#         "087-933-0702",
#         "421-382-2477"
#     ],
#     "weights": [
#         132
#     ],
#     "height": 153,
#     "bp_readings": [
#         {
#             "Systolic": 142,
#             "Diastolic": 79,
#             "Rate": 103
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 81,
#             "Rate": 79
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 70,
#             "Rate": 64
#         }
#     ]
# }
# {
#     "_id": 29,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "068-555-9335",
#         "962-181-5644"
#     ],
#     "weights": [
#         163,
#         379,
#         280,
#         91,
#         273
#     ],
#     "height": 145,
#     "bp_readings": [
#         {
#             "Systolic": 126,
#             "Diastolic": 92,
#             "Rate": 107
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 88,
#             "Rate": 110
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 99,
#             "Rate": 92
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 96,
#             "Rate": 61
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 78,
#             "Rate": 98
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 79,
#             "Rate": 100
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 74,
#             "Rate": 75
#         }
#     ]
# }
# {
#     "_id": 31,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "411-975-1214",
#         "438-433-2826"
#     ],
#     "weights": [
#         334,
#         198,
#         104,
#         194
#     ],
#     "height": 172,
#     "bp_readings": [
#         {
#             "Systolic": 142,
#             "Diastolic": 93,
#             "Rate": 110
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 99,
#             "Rate": 107
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 72,
#             "Rate": 93
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 84,
#             "Rate": 70
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 96,
#             "Rate": 97
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 78,
#             "Rate": 90
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 94,
#             "Rate": 109
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 89,
#             "Rate": 103
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 98,
#             "Rate": 63
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 70,
#             "Rate": 108
#         }
#     ]
# }
# {
#     "_id": 36,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "636-870-5319",
#         "895-034-1896",
#         "543-304-8986",
#         "848-344-1469"
#     ],
#     "weights": [
#         141,
#         319,
#         353,
#         266
#     ],
#     "height": 184,
#     "bp_readings": [
#         {
#             "Systolic": 101,
#             "Diastolic": 76,
#             "Rate": 84
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 73,
#             "Rate": 100
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 92,
#             "Rate": 95
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 81,
#             "Rate": 89
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 90,
#             "Rate": 84
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 76,
#             "Rate": 91
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 94,
#             "Rate": 82
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 93,
#             "Rate": 102
#         }
#     ]
# }
# {
#     "_id": 40,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "040-254-9970",
#         "035-280-9701",
#         "840-678-2039",
#         "757-744-7500"
#     ],
#     "weights": [
#         337,
#         119
#     ],
#     "height": 105,
#     "bp_readings": [
#         {
#             "Systolic": 118,
#             "Diastolic": 89,
#             "Rate": 90
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 81,
#             "Rate": 79
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 88,
#             "Rate": 69
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 97,
#             "Rate": 63
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 71,
#             "Rate": 107
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 71,
#             "Rate": 101
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 76,
#             "Rate": 65
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 96,
#             "Rate": 102
#         }
#     ]
# }

# %%
# we can also check for greater than, greater than equal, less than, less than equal
query = { "bp_readings.Systolic" : {"$gte" : 130}} # in this style, you need all fields - so this one won't return anything
doc = collection.find(query)
for record in doc:
    print(record)
    #print(json.dumps(record, indent=4))
# Out:
# {'_id': 1, 'office_num': [8], 'patient_info': {'fname': 'Jordan', 'lname': 'Smith', 'mname': 'Jane'}, 'patient_numbers': ['510-494-1528', '160-449-8315', '628-319-5148', '564-233-3413'], 'weights': [125, 153, 266, 387], 'height': 198, 'bp_readings': [{'Systolic': 102, 'Diastolic': 91, 'Rate': 74}, {'Systolic': 122, 'Diastolic': 98, 'Rate': 104}, {'Systolic': 130, 'Diastolic': 80, 'Rate': 108}, {'Systolic': 112, 'Diastolic': 83, 'Rate': 86}, {'Systolic': 126, 'Diastolic': 83, 'Rate': 80}, {'Systolic': 103, 'Diastolic': 70, 'Rate': 77}, {'Systolic': 100, 'Diastolic': 73, 'Rate': 94}, {'Systolic': 121, 'Diastolic': 79, 'Rate': 84}, {'Systolic': 135, 'Diastolic': 95, 'Rate': 87}], 'comments': 'good patient', 'readings': [{'Systolic': 999, 'Diastolic': 999, 'Rate': 999}]}
# {'_id': 2, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['528-130-0797', '253-298-7373', '898-939-6286'], 'weights': [149, 326, 153, 256, 222], 'height': 139, 'bp_readings': [{'Systolic': 135, 'Diastolic': 71, 'Rate': 82}, {'Systolic': 121, 'Diastolic': 80, 'Rate': 65}, {'Systolic': 150, 'Diastolic': 72, 'Rate': 110}, {'Systolic': 119, 'Diastolic': 74, 'Rate': 106}, {'Systolic': 125, 'Diastolic': 94, 'Rate': 75}]}
# {'_id': 3, 'office_num': [5], 'patient_info': {'fname': 'Liam', 'lname': 'Jones'}, 'patient_numbers': ['644-156-9992', '863-337-8150', '999-770-5886', '115-513-7787'], 'weights': [257, 300, 346, 358], 'height': 113, 'bp_readings': [{'Systolic': 143, 'Diastolic': 96, 'Rate': 98}, {'Systolic': 118, 'Diastolic': 87, 'Rate': 70}, {'Systolic': 131, 'Diastolic': 80, 'Rate': 100}, {'Systolic': 145, 'Diastolic': 95, 'Rate': 100}]}
# {'_id': 4, 'office_num': [6], 'patient_info': {'fname': 'Richard', 'lname': 'Hart'}, 'patient_numbers': ['120-553-4906', '284-176-5012', '493-727-1391', '270-698-7209'], 'weights': [132], 'height': 119, 'bp_readings': [{'Systolic': 129, 'Diastolic': 99, 'Rate': 107}, {'Systolic': 139, 'Diastolic': 86, 'Rate': 75}, {'Systolic': 110, 'Diastolic': 94, 'Rate': 84}, {'Systolic': 146, 'Diastolic': 99, 'Rate': 104}, {'Systolic': 103, 'Diastolic': 80, 'Rate': 81}, {'Systolic': 107, 'Diastolic': 72, 'Rate': 84}, {'Systolic': 109, 'Diastolic': 98, 'Rate': 94}]}
# {'_id': 5, 'office_num': [4], 'patient_info': {'fname': 'Jerry', 'lname': 'Boone'}, 'patient_numbers': ['049-092-0196', '134-731-0171', '473-607-5803'], 'weights': [212, 350, 269], 'height': 162, 'bp_readings': [{'Systolic': 107, 'Diastolic': 73, 'Rate': 70}, {'Systolic': 111, 'Diastolic': 78, 'Rate': 101}, {'Systolic': 123, 'Diastolic': 81, 'Rate': 85}, {'Systolic': 135, 'Diastolic': 95, 'Rate': 65}, {'Systolic': 101, 'Diastolic': 91, 'Rate': 78}, {'Systolic': 146, 'Diastolic': 82, 'Rate': 109}, {'Systolic': 120, 'Diastolic': 96, 'Rate': 72}, {'Systolic': 142, 'Diastolic': 94, 'Rate': 87}, {'Systolic': 130, 'Diastolic': 80, 'Rate': 100}]}
# {'_id': 7, 'office_num': [8], 'patient_info': {'fname': 'Liam', 'lname': ' Fox'}, 'patient_numbers': ['653-684-7515', '045-819-7256'], 'weights': [98, 180, 162, 379, 266], 'height': 135, 'bp_readings': [{'Systolic': 125, 'Diastolic': 85, 'Rate': 63}, {'Systolic': 144, 'Diastolic': 71, 'Rate': 97}, {'Systolic': 150, 'Diastolic': 74, 'Rate': 108}, {'Systolic': 126, 'Diastolic': 95, 'Rate': 101}, {'Systolic': 134, 'Diastolic': 84, 'Rate': 79}, {'Systolic': 114, 'Diastolic': 81, 'Rate': 95}, {'Systolic': 104, 'Diastolic': 74, 'Rate': 103}, {'Systolic': 137, 'Diastolic': 94, 'Rate': 109}, {'Systolic': 112, 'Diastolic': 79, 'Rate': 61}, {'Systolic': 135, 'Diastolic': 77, 'Rate': 88}]}
# {'_id': 8, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Boone'}, 'patient_numbers': ['118-146-4696', '853-751-9706', '631-269-6143', '128-218-4240'], 'weights': [193, 385, 194, 160, 196], 'height': 189, 'bp_readings': [{'Systolic': 142, 'Diastolic': 78, 'Rate': 93}, {'Systolic': 101, 'Diastolic': 76, 'Rate': 73}, {'Systolic': 140, 'Diastolic': 87, 'Rate': 107}, {'Systolic': 140, 'Diastolic': 83, 'Rate': 70}, {'Systolic': 149, 'Diastolic': 89, 'Rate': 92}, {'Systolic': 103, 'Diastolic': 95, 'Rate': 75}, {'Systolic': 128, 'Diastolic': 80, 'Rate': 88}, {'Systolic': 111, 'Diastolic': 90, 'Rate': 95}]}
# {'_id': 9, 'office_num': [5], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['893-421-2922', '786-231-9620', '501-218-5126'], 'weights': [373, 194, 203, 292, 95], 'height': 138, 'bp_readings': [{'Systolic': 123, 'Diastolic': 89, 'Rate': 60}, {'Systolic': 150, 'Diastolic': 74, 'Rate': 108}, {'Systolic': 119, 'Diastolic': 84, 'Rate': 93}, {'Systolic': 143, 'Diastolic': 85, 'Rate': 87}, {'Systolic': 104, 'Diastolic': 92, 'Rate': 79}, {'Systolic': 109, 'Diastolic': 97, 'Rate': 93}, {'Systolic': 119, 'Diastolic': 81, 'Rate': 64}, {'Systolic': 139, 'Diastolic': 87, 'Rate': 95}, {'Systolic': 150, 'Diastolic': 84, 'Rate': 83}, {'Systolic': 137, 'Diastolic': 71, 'Rate': 88}]}
# {'_id': 10, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Granger'}, 'patient_numbers': ['914-270-1796', '007-332-2036', '727-933-2066', '181-475-8629'], 'weights': [178, 111, 240, 254], 'height': 166, 'bp_readings': [{'Systolic': 101, 'Diastolic': 80, 'Rate': 86}, {'Systolic': 110, 'Diastolic': 88, 'Rate': 85}, {'Systolic': 136, 'Diastolic': 82, 'Rate': 67}, {'Systolic': 115, 'Diastolic': 94, 'Rate': 61}, {'Systolic': 115, 'Diastolic': 89, 'Rate': 73}, {'Systolic': 138, 'Diastolic': 97, 'Rate': 61}, {'Systolic': 107, 'Diastolic': 98, 'Rate': 95}, {'Systolic': 135, 'Diastolic': 72, 'Rate': 97}, {'Systolic': 123, 'Diastolic': 98, 'Rate': 79}]}
# {'_id': 11, 'office_num': [9], 'patient_info': {'fname': 'Richard', 'lname': 'Boone'}, 'patient_numbers': ['127-046-8212', '659-052-2244', '839-910-6764'], 'weights': [101, 392, 355, 261], 'height': 116, 'bp_readings': [{'Systolic': 132, 'Diastolic': 92, 'Rate': 67}, {'Systolic': 100, 'Diastolic': 85, 'Rate': 66}, {'Systolic': 146, 'Diastolic': 85, 'Rate': 77}, {'Systolic': 111, 'Diastolic': 81, 'Rate': 63}, {'Systolic': 100, 'Diastolic': 71, 'Rate': 96}, {'Systolic': 100, 'Diastolic': 89, 'Rate': 110}]}
# {'_id': 12, 'office_num': [1], 'patient_info': {'fname': 'Jordan', 'lname': 'Madden'}, 'patient_numbers': ['545-438-3955', '837-914-3989'], 'weights': [160, 388, 154, 312, 286], 'height': 129, 'bp_readings': [{'Systolic': 110, 'Diastolic': 90, 'Rate': 88}, {'Systolic': 150, 'Diastolic': 88, 'Rate': 74}, {'Systolic': 138, 'Diastolic': 97, 'Rate': 109}, {'Systolic': 128, 'Diastolic': 78, 'Rate': 76}, {'Systolic': 139, 'Diastolic': 96, 'Rate': 77}]}
# {'_id': 13, 'office_num': [6], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['713-176-8049', '496-331-4552', '137-364-7076', '051-030-8369'], 'weights': [291, 177], 'height': 154, 'bp_readings': [{'Systolic': 122, 'Diastolic': 75, 'Rate': 92}, {'Systolic': 104, 'Diastolic': 81, 'Rate': 100}, {'Systolic': 122, 'Diastolic': 71, 'Rate': 78}, {'Systolic': 141, 'Diastolic': 82, 'Rate': 98}]}
# {'_id': 15, 'office_num': [6], 'patient_info': {'fname': 'Jerry', 'lname': 'Hart'}, 'patient_numbers': ['492-609-7919', '552-344-7173', '381-139-4744'], 'weights': [359, 137, 215], 'height': 155, 'bp_readings': [{'Systolic': 149, 'Diastolic': 90, 'Rate': 106}, {'Systolic': 137, 'Diastolic': 93, 'Rate': 109}, {'Systolic': 113, 'Diastolic': 73, 'Rate': 87}, {'Systolic': 101, 'Diastolic': 70, 'Rate': 84}, {'Systolic': 113, 'Diastolic': 85, 'Rate': 78}, {'Systolic': 143, 'Diastolic': 93, 'Rate': 102}, {'Systolic': 125, 'Diastolic': 74, 'Rate': 74}, {'Systolic': 116, 'Diastolic': 72, 'Rate': 109}, {'Systolic': 130, 'Diastolic': 77, 'Rate': 63}, {'Systolic': 146, 'Diastolic': 89, 'Rate': 74}]}
# {'_id': 16, 'office_num': [1], 'patient_info': {'fname': 'Jordan', 'lname': 'Hale'}, 'patient_numbers': ['154-090-3578', '670-064-8514', '014-666-6302'], 'weights': [202, 272, 116], 'height': 137, 'bp_readings': [{'Systolic': 141, 'Diastolic': 80, 'Rate': 104}, {'Systolic': 125, 'Diastolic': 95, 'Rate': 82}, {'Systolic': 105, 'Diastolic': 84, 'Rate': 99}, {'Systolic': 124, 'Diastolic': 70, 'Rate': 65}, {'Systolic': 131, 'Diastolic': 77, 'Rate': 60}, {'Systolic': 122, 'Diastolic': 79, 'Rate': 67}, {'Systolic': 101, 'Diastolic': 74, 'Rate': 92}, {'Systolic': 114, 'Diastolic': 80, 'Rate': 101}, {'Systolic': 126, 'Diastolic': 87, 'Rate': 78}]}
# {'_id': 17, 'office_num': [4], 'patient_info': {'fname': 'Betty', 'lname': ' Fox'}, 'patient_numbers': ['369-778-4121', '014-192-8069', '129-610-7272', '744-317-8177'], 'weights': [224, 121], 'height': 186, 'bp_readings': [{'Systolic': 108, 'Diastolic': 94, 'Rate': 94}, {'Systolic': 115, 'Diastolic': 96, 'Rate': 89}, {'Systolic': 102, 'Diastolic': 73, 'Rate': 85}, {'Systolic': 143, 'Diastolic': 78, 'Rate': 100}, {'Systolic': 117, 'Diastolic': 98, 'Rate': 64}, {'Systolic': 100, 'Diastolic': 84, 'Rate': 97}]}
# {'_id': 18, 'office_num': [10], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Madden'}, 'patient_numbers': ['765-638-7096', '087-933-0702', '421-382-2477'], 'weights': [132], 'height': 153, 'bp_readings': [{'Systolic': 142, 'Diastolic': 79, 'Rate': 103}, {'Systolic': 149, 'Diastolic': 81, 'Rate': 79}, {'Systolic': 101, 'Diastolic': 70, 'Rate': 64}]}
# {'_id': 20, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['972-440-9434', '082-472-6661', '519-292-3029', '483-712-8004'], 'weights': [260], 'height': 186, 'bp_readings': [{'Systolic': 117, 'Diastolic': 84, 'Rate': 98}, {'Systolic': 102, 'Diastolic': 70, 'Rate': 88}, {'Systolic': 139, 'Diastolic': 86, 'Rate': 99}, {'Systolic': 110, 'Diastolic': 81, 'Rate': 95}, {'Systolic': 147, 'Diastolic': 87, 'Rate': 65}, {'Systolic': 143, 'Diastolic': 82, 'Rate': 102}, {'Systolic': 129, 'Diastolic': 98, 'Rate': 90}]}
# {'_id': 21, 'office_num': [2], 'patient_info': {'fname': 'Liam', 'lname': 'Boone'}, 'patient_numbers': ['116-438-2583', '510-457-3871'], 'weights': [369, 256, 339, 309], 'height': 110, 'bp_readings': [{'Systolic': 144, 'Diastolic': 96, 'Rate': 95}, {'Systolic': 108, 'Diastolic': 91, 'Rate': 84}]}
# {'_id': 22, 'office_num': [7], 'patient_info': {'fname': 'Susan', 'lname': 'Hart'}, 'patient_numbers': ['980-365-7411', '026-674-4727', '488-419-7640', '771-907-9718'], 'weights': [120], 'height': 108, 'bp_readings': [{'Systolic': 127, 'Diastolic': 92, 'Rate': 107}, {'Systolic': 132, 'Diastolic': 81, 'Rate': 97}, {'Systolic': 126, 'Diastolic': 71, 'Rate': 71}, {'Systolic': 124, 'Diastolic': 84, 'Rate': 110}]}
# {'_id': 23, 'office_num': [6], 'patient_info': {'fname': 'Tom', 'lname': 'Madden'}, 'patient_numbers': ['514-790-2184', '021-408-6710', '587-589-3021'], 'weights': [316, 103, 304], 'height': 126, 'bp_readings': [{'Systolic': 128, 'Diastolic': 79, 'Rate': 94}, {'Systolic': 106, 'Diastolic': 85, 'Rate': 85}, {'Systolic': 127, 'Diastolic': 79, 'Rate': 81}, {'Systolic': 140, 'Diastolic': 95, 'Rate': 96}, {'Systolic': 114, 'Diastolic': 93, 'Rate': 106}, {'Systolic': 109, 'Diastolic': 85, 'Rate': 70}, {'Systolic': 117, 'Diastolic': 80, 'Rate': 80}, {'Systolic': 119, 'Diastolic': 90, 'Rate': 83}, {'Systolic': 125, 'Diastolic': 98, 'Rate': 98}, {'Systolic': 126, 'Diastolic': 94, 'Rate': 73}]}
# {'_id': 25, 'office_num': [6], 'patient_info': {'fname': 'Jack', 'lname': 'Smith'}, 'patient_numbers': ['308-994-0395', '918-832-0218', '048-908-1600'], 'weights': [183], 'height': 146, 'bp_readings': [{'Systolic': 120, 'Diastolic': 71, 'Rate': 105}, {'Systolic': 126, 'Diastolic': 94, 'Rate': 101}, {'Systolic': 116, 'Diastolic': 84, 'Rate': 99}, {'Systolic': 143, 'Diastolic': 99, 'Rate': 97}, {'Systolic': 140, 'Diastolic': 90, 'Rate': 84}, {'Systolic': 136, 'Diastolic': 99, 'Rate': 68}, {'Systolic': 107, 'Diastolic': 93, 'Rate': 93}, {'Systolic': 124, 'Diastolic': 79, 'Rate': 67}]}
# {'_id': 26, 'office_num': [4], 'patient_info': {'fname': 'Betty', 'lname': 'Hale'}, 'patient_numbers': ['710-170-1715', '347-757-6450', '458-243-1366'], 'weights': [294, 380, 162, 337, 250], 'height': 144, 'bp_readings': [{'Systolic': 109, 'Diastolic': 95, 'Rate': 95}, {'Systolic': 109, 'Diastolic': 76, 'Rate': 83}, {'Systolic': 105, 'Diastolic': 84, 'Rate': 81}, {'Systolic': 114, 'Diastolic': 97, 'Rate': 82}, {'Systolic': 136, 'Diastolic': 97, 'Rate': 88}]}
# {'_id': 27, 'office_num': [9], 'patient_info': {'fname': 'Liam', 'lname': 'Smith'}, 'patient_numbers': ['358-885-6398', '296-386-9448', '846-186-4133', '113-735-7625'], 'weights': [96, 257, 95], 'height': 177, 'bp_readings': [{'Systolic': 109, 'Diastolic': 79, 'Rate': 102}, {'Systolic': 125, 'Diastolic': 71, 'Rate': 88}, {'Systolic': 129, 'Diastolic': 82, 'Rate': 70}, {'Systolic': 122, 'Diastolic': 92, 'Rate': 103}, {'Systolic': 114, 'Diastolic': 97, 'Rate': 105}, {'Systolic': 135, 'Diastolic': 81, 'Rate': 81}, {'Systolic': 103, 'Diastolic': 99, 'Rate': 100}, {'Systolic': 105, 'Diastolic': 71, 'Rate': 60}, {'Systolic': 147, 'Diastolic': 78, 'Rate': 64}]}
# {'_id': 28, 'office_num': [4], 'patient_info': {'fname': 'Susan', 'lname': ' Fox'}, 'patient_numbers': ['651-740-4519', '004-323-0319'], 'weights': [200, 196], 'height': 124, 'bp_readings': [{'Systolic': 118, 'Diastolic': 79, 'Rate': 74}, {'Systolic': 126, 'Diastolic': 89, 'Rate': 82}, {'Systolic': 137, 'Diastolic': 76, 'Rate': 88}]}
# {'_id': 29, 'office_num': [2], 'patient_info': {'fname': 'Liam', 'lname': 'Boone'}, 'patient_numbers': ['068-555-9335', '962-181-5644'], 'weights': [163, 379, 280, 91, 273], 'height': 145, 'bp_readings': [{'Systolic': 126, 'Diastolic': 92, 'Rate': 107}, {'Systolic': 149, 'Diastolic': 88, 'Rate': 110}, {'Systolic': 141, 'Diastolic': 99, 'Rate': 92}, {'Systolic': 142, 'Diastolic': 96, 'Rate': 61}, {'Systolic': 126, 'Diastolic': 78, 'Rate': 98}, {'Systolic': 103, 'Diastolic': 79, 'Rate': 100}, {'Systolic': 148, 'Diastolic': 74, 'Rate': 75}]}
# {'_id': 30, 'office_num': [3], 'patient_info': {'fname': 'Jack', 'lname': 'Langston'}, 'patient_numbers': ['394-907-9040', '584-742-0182', '652-925-6579'], 'weights': [325, 270], 'height': 191, 'bp_readings': [{'Systolic': 113, 'Diastolic': 77, 'Rate': 104}, {'Systolic': 126, 'Diastolic': 86, 'Rate': 94}, {'Systolic': 123, 'Diastolic': 90, 'Rate': 74}, {'Systolic': 117, 'Diastolic': 91, 'Rate': 81}, {'Systolic': 140, 'Diastolic': 98, 'Rate': 106}, {'Systolic': 150, 'Diastolic': 73, 'Rate': 69}, {'Systolic': 112, 'Diastolic': 70, 'Rate': 73}, {'Systolic': 131, 'Diastolic': 87, 'Rate': 80}, {'Systolic': 110, 'Diastolic': 95, 'Rate': 61}]}
# {'_id': 31, 'office_num': [5], 'patient_info': {'fname': 'Ethan', 'lname': 'Hale'}, 'patient_numbers': ['411-975-1214', '438-433-2826'], 'weights': [334, 198, 104, 194], 'height': 172, 'bp_readings': [{'Systolic': 142, 'Diastolic': 93, 'Rate': 110}, {'Systolic': 144, 'Diastolic': 99, 'Rate': 107}, {'Systolic': 143, 'Diastolic': 72, 'Rate': 93}, {'Systolic': 107, 'Diastolic': 84, 'Rate': 70}, {'Systolic': 100, 'Diastolic': 96, 'Rate': 97}, {'Systolic': 145, 'Diastolic': 78, 'Rate': 90}, {'Systolic': 113, 'Diastolic': 94, 'Rate': 109}, {'Systolic': 133, 'Diastolic': 89, 'Rate': 103}, {'Systolic': 126, 'Diastolic': 98, 'Rate': 63}, {'Systolic': 131, 'Diastolic': 70, 'Rate': 108}]}
# {'_id': 32, 'office_num': [3], 'patient_info': {'fname': 'Tom', 'lname': 'Hart'}, 'patient_numbers': ['134-212-3252', '596-871-2312', '171-337-7720'], 'weights': [378, 231, 102, 309, 358], 'height': 147, 'bp_readings': [{'Systolic': 126, 'Diastolic': 84, 'Rate': 68}, {'Systolic': 118, 'Diastolic': 76, 'Rate': 77}, {'Systolic': 149, 'Diastolic': 76, 'Rate': 73}, {'Systolic': 100, 'Diastolic': 89, 'Rate': 103}, {'Systolic': 116, 'Diastolic': 81, 'Rate': 67}]}
# {'_id': 33, 'office_num': [1], 'patient_info': {'fname': 'Richard', 'lname': 'Jones'}, 'patient_numbers': ['622-740-2217', '895-898-7674', '159-362-8489', '667-242-9724'], 'weights': [380, 197, 161, 283, 382], 'height': 116, 'bp_readings': [{'Systolic': 102, 'Diastolic': 79, 'Rate': 80}, {'Systolic': 131, 'Diastolic': 97, 'Rate': 105}, {'Systolic': 147, 'Diastolic': 86, 'Rate': 80}, {'Systolic': 138, 'Diastolic': 89, 'Rate': 109}, {'Systolic': 113, 'Diastolic': 94, 'Rate': 67}, {'Systolic': 101, 'Diastolic': 84, 'Rate': 106}, {'Systolic': 100, 'Diastolic': 90, 'Rate': 73}, {'Systolic': 104, 'Diastolic': 73, 'Rate': 72}, {'Systolic': 119, 'Diastolic': 94, 'Rate': 102}, {'Systolic': 127, 'Diastolic': 79, 'Rate': 81}]}
# {'_id': 34, 'office_num': [1], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['250-489-8136', '209-189-7571'], 'weights': [254, 216, 296], 'height': 177, 'bp_readings': [{'Systolic': 144, 'Diastolic': 91, 'Rate': 89}, {'Systolic': 124, 'Diastolic': 87, 'Rate': 108}, {'Systolic': 101, 'Diastolic': 74, 'Rate': 78}, {'Systolic': 136, 'Diastolic': 94, 'Rate': 67}, {'Systolic': 100, 'Diastolic': 73, 'Rate': 109}, {'Systolic': 128, 'Diastolic': 99, 'Rate': 89}, {'Systolic': 148, 'Diastolic': 77, 'Rate': 80}, {'Systolic': 140, 'Diastolic': 75, 'Rate': 77}, {'Systolic': 135, 'Diastolic': 85, 'Rate': 75}, {'Systolic': 124, 'Diastolic': 71, 'Rate': 94}]}
# {'_id': 35, 'office_num': [9], 'patient_info': {'fname': 'Jerry', 'lname': 'Langston'}, 'patient_numbers': ['631-443-6485', '227-670-5130', '593-269-5740'], 'weights': [168, 286, 354, 319], 'height': 106, 'bp_readings': [{'Systolic': 103, 'Diastolic': 84, 'Rate': 100}, {'Systolic': 129, 'Diastolic': 91, 'Rate': 94}, {'Systolic': 143, 'Diastolic': 78, 'Rate': 91}, {'Systolic': 118, 'Diastolic': 77, 'Rate': 80}, {'Systolic': 108, 'Diastolic': 96, 'Rate': 89}, {'Systolic': 108, 'Diastolic': 89, 'Rate': 73}, {'Systolic': 132, 'Diastolic': 83, 'Rate': 60}]}
# {'_id': 36, 'office_num': [9], 'patient_info': {'fname': 'James', 'lname': 'Hale'}, 'patient_numbers': ['636-870-5319', '895-034-1896', '543-304-8986', '848-344-1469'], 'weights': [141, 319, 353, 266], 'height': 184, 'bp_readings': [{'Systolic': 101, 'Diastolic': 76, 'Rate': 84}, {'Systolic': 109, 'Diastolic': 73, 'Rate': 100}, {'Systolic': 113, 'Diastolic': 92, 'Rate': 95}, {'Systolic': 136, 'Diastolic': 81, 'Rate': 89}, {'Systolic': 132, 'Diastolic': 90, 'Rate': 84}, {'Systolic': 148, 'Diastolic': 76, 'Rate': 91}, {'Systolic': 134, 'Diastolic': 94, 'Rate': 82}, {'Systolic': 142, 'Diastolic': 93, 'Rate': 102}]}
# {'_id': 37, 'office_num': [1], 'patient_info': {'fname': 'Liam', 'lname': ' Fox'}, 'patient_numbers': ['378-533-7858', '537-754-1935', '819-478-5505', '180-802-2297'], 'weights': [256, 223, 372], 'height': 106, 'bp_readings': [{'Systolic': 100, 'Diastolic': 87, 'Rate': 93}, {'Systolic': 146, 'Diastolic': 73, 'Rate': 75}, {'Systolic': 137, 'Diastolic': 84, 'Rate': 81}, {'Systolic': 128, 'Diastolic': 81, 'Rate': 81}]}
# {'_id': 38, 'office_num': [9], 'patient_info': {'fname': 'Jack', 'lname': 'Granger'}, 'patient_numbers': ['888-114-1026', '625-676-9429', '903-783-1338'], 'weights': [398, 331, 130], 'height': 155, 'bp_readings': [{'Systolic': 130, 'Diastolic': 79, 'Rate': 79}, {'Systolic': 123, 'Diastolic': 99, 'Rate': 108}, {'Systolic': 107, 'Diastolic': 98, 'Rate': 89}, {'Systolic': 109, 'Diastolic': 95, 'Rate': 105}, {'Systolic': 120, 'Diastolic': 84, 'Rate': 91}, {'Systolic': 143, 'Diastolic': 85, 'Rate': 61}]}
# {'_id': 39, 'office_num': [9], 'patient_info': {'fname': 'Susan', 'lname': 'Smith'}, 'patient_numbers': ['227-869-3656', '410-846-3569'], 'weights': [169, 92, 172, 212], 'height': 121, 'bp_readings': [{'Systolic': 128, 'Diastolic': 74, 'Rate': 63}, {'Systolic': 145, 'Diastolic': 98, 'Rate': 68}, {'Systolic': 115, 'Diastolic': 98, 'Rate': 105}, {'Systolic': 137, 'Diastolic': 72, 'Rate': 89}, {'Systolic': 138, 'Diastolic': 82, 'Rate': 101}, {'Systolic': 139, 'Diastolic': 85, 'Rate': 73}, {'Systolic': 135, 'Diastolic': 92, 'Rate': 85}, {'Systolic': 129, 'Diastolic': 74, 'Rate': 66}]}
# {'_id': 40, 'office_num': [2], 'patient_info': {'fname': 'Jack', 'lname': 'Jones'}, 'patient_numbers': ['040-254-9970', '035-280-9701', '840-678-2039', '757-744-7500'], 'weights': [337, 119], 'height': 105, 'bp_readings': [{'Systolic': 118, 'Diastolic': 89, 'Rate': 90}, {'Systolic': 142, 'Diastolic': 81, 'Rate': 79}, {'Systolic': 110, 'Diastolic': 88, 'Rate': 69}, {'Systolic': 136, 'Diastolic': 97, 'Rate': 63}, {'Systolic': 130, 'Diastolic': 71, 'Rate': 107}, {'Systolic': 130, 'Diastolic': 71, 'Rate': 101}, {'Systolic': 135, 'Diastolic': 76, 'Rate': 65}, {'Systolic': 100, 'Diastolic': 96, 'Rate': 102}]}
# {'_id': 41, 'office_num': [4], 'patient_info': {'fname': 'Richard', 'lname': 'Hart'}, 'patient_numbers': ['456-669-4613', '630-135-0952'], 'weights': [313], 'height': 120, 'bp_readings': [{'Systolic': 110, 'Diastolic': 75, 'Rate': 96}, {'Systolic': 108, 'Diastolic': 78, 'Rate': 102}, {'Systolic': 113, 'Diastolic': 94, 'Rate': 109}, {'Systolic': 147, 'Diastolic': 76, 'Rate': 63}, {'Systolic': 120, 'Diastolic': 75, 'Rate': 81}, {'Systolic': 131, 'Diastolic': 93, 'Rate': 91}, {'Systolic': 104, 'Diastolic': 74, 'Rate': 90}, {'Systolic': 149, 'Diastolic': 88, 'Rate': 105}]}
# {'_id': 42, 'office_num': [10], 'patient_info': {'fname': 'Liam', 'lname': 'Smith'}, 'patient_numbers': ['855-871-4130', '931-621-4641'], 'weights': [96, 132], 'height': 165, 'bp_readings': [{'Systolic': 124, 'Diastolic': 79, 'Rate': 98}, {'Systolic': 147, 'Diastolic': 89, 'Rate': 62}, {'Systolic': 127, 'Diastolic': 99, 'Rate': 89}, {'Systolic': 104, 'Diastolic': 80, 'Rate': 86}, {'Systolic': 146, 'Diastolic': 75, 'Rate': 83}]}
# {'_id': 43, 'office_num': [2], 'patient_info': {'fname': 'Susan', 'lname': ' Fox'}, 'patient_numbers': ['090-196-5242', '407-722-8626'], 'weights': [373, 100, 398, 338], 'height': 130, 'bp_readings': [{'Systolic': 115, 'Diastolic': 72, 'Rate': 64}, {'Systolic': 111, 'Diastolic': 84, 'Rate': 61}, {'Systolic': 108, 'Diastolic': 85, 'Rate': 105}, {'Systolic': 121, 'Diastolic': 95, 'Rate': 97}, {'Systolic': 147, 'Diastolic': 71, 'Rate': 63}, {'Systolic': 117, 'Diastolic': 96, 'Rate': 61}, {'Systolic': 117, 'Diastolic': 74, 'Rate': 63}, {'Systolic': 134, 'Diastolic': 96, 'Rate': 100}, {'Systolic': 120, 'Diastolic': 91, 'Rate': 105}, {'Systolic': 138, 'Diastolic': 72, 'Rate': 74}]}
# {'_id': 44, 'office_num': [3], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['997-540-6376', '570-769-9027', '774-466-1209'], 'weights': [309], 'height': 172, 'bp_readings': [{'Systolic': 137, 'Diastolic': 89, 'Rate': 88}, {'Systolic': 104, 'Diastolic': 75, 'Rate': 95}, {'Systolic': 130, 'Diastolic': 82, 'Rate': 71}, {'Systolic': 128, 'Diastolic': 98, 'Rate': 88}, {'Systolic': 137, 'Diastolic': 73, 'Rate': 81}, {'Systolic': 120, 'Diastolic': 91, 'Rate': 61}, {'Systolic': 145, 'Diastolic': 70, 'Rate': 109}, {'Systolic': 103, 'Diastolic': 74, 'Rate': 63}, {'Systolic': 113, 'Diastolic': 83, 'Rate': 74}, {'Systolic': 132, 'Diastolic': 96, 'Rate': 108}]}
# {'_id': 45, 'office_num': [9], 'patient_info': {'fname': 'James', 'lname': 'Langston'}, 'patient_numbers': ['210-570-9775', '130-469-7826'], 'weights': [242, 154, 227, 285], 'height': 160, 'bp_readings': [{'Systolic': 144, 'Diastolic': 82, 'Rate': 97}, {'Systolic': 119, 'Diastolic': 77, 'Rate': 110}]}
# {'_id': 46, 'office_num': [3], 'patient_info': {'fname': 'Betty', 'lname': 'Madden'}, 'patient_numbers': ['465-521-6381', '396-414-4523', '914-527-0689', '884-089-7413'], 'weights': [388, 227, 174, 389], 'height': 127, 'bp_readings': [{'Systolic': 138, 'Diastolic': 90, 'Rate': 92}, {'Systolic': 132, 'Diastolic': 84, 'Rate': 92}, {'Systolic': 121, 'Diastolic': 98, 'Rate': 65}, {'Systolic': 124, 'Diastolic': 98, 'Rate': 102}, {'Systolic': 117, 'Diastolic': 78, 'Rate': 63}, {'Systolic': 139, 'Diastolic': 86, 'Rate': 86}, {'Systolic': 135, 'Diastolic': 98, 'Rate': 106}, {'Systolic': 105, 'Diastolic': 93, 'Rate': 66}, {'Systolic': 144, 'Diastolic': 89, 'Rate': 66}]}
# {'_id': 47, 'office_num': [7], 'patient_info': {'fname': 'Betty', 'lname': 'Jones'}, 'patient_numbers': ['507-610-3989', '115-430-8233', '225-908-6038'], 'weights': [224], 'height': 156, 'bp_readings': [{'Systolic': 114, 'Diastolic': 78, 'Rate': 95}, {'Systolic': 144, 'Diastolic': 79, 'Rate': 62}, {'Systolic': 141, 'Diastolic': 89, 'Rate': 96}, {'Systolic': 114, 'Diastolic': 83, 'Rate': 77}, {'Systolic': 128, 'Diastolic': 85, 'Rate': 90}, {'Systolic': 127, 'Diastolic': 80, 'Rate': 63}, {'Systolic': 138, 'Diastolic': 85, 'Rate': 105}]}
# {'_id': 48, 'office_num': [9], 'patient_info': {'fname': 'Betty', 'lname': 'Jones'}, 'patient_numbers': ['974-983-8821', '042-974-9089'], 'weights': [205, 355, 173, 316, 357], 'height': 149, 'bp_readings': [{'Systolic': 131, 'Diastolic': 73, 'Rate': 107}, {'Systolic': 113, 'Diastolic': 85, 'Rate': 101}, {'Systolic': 100, 'Diastolic': 76, 'Rate': 110}, {'Systolic': 111, 'Diastolic': 77, 'Rate': 69}, {'Systolic': 123, 'Diastolic': 83, 'Rate': 99}, {'Systolic': 109, 'Diastolic': 71, 'Rate': 76}, {'Systolic': 119, 'Diastolic': 78, 'Rate': 83}, {'Systolic': 107, 'Diastolic': 77, 'Rate': 64}, {'Systolic': 126, 'Diastolic': 84, 'Rate': 65}]}
# {'_id': 49, 'office_num': [2], 'patient_info': {'fname': 'Betty', 'lname': 'Smith'}, 'patient_numbers': ['552-529-6576', '546-675-3594', '895-723-5862', '472-705-2764'], 'weights': [365], 'height': 142, 'bp_readings': [{'Systolic': 150, 'Diastolic': 97, 'Rate': 66}, {'Systolic': 131, 'Diastolic': 78, 'Rate': 105}, {'Systolic': 128, 'Diastolic': 82, 'Rate': 86}, {'Systolic': 132, 'Diastolic': 73, 'Rate': 66}]}

# %% [markdown]
# Another approach is to use \$elemMatch. This will conduct an element wise match of the fields in an array of embedded documents.

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : 104}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 7,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "653-684-7515",
#         "045-819-7256"
#     ],
#     "weights": [
#         98,
#         180,
#         162,
#         379,
#         266
#     ],
#     "height": 135,
#     "bp_readings": [
#         {
#             "Systolic": 125,
#             "Diastolic": 85,
#             "Rate": 63
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 71,
#             "Rate": 97
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 108
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 95,
#             "Rate": 101
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 84,
#             "Rate": 79
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 81,
#             "Rate": 95
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 74,
#             "Rate": 103
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 94,
#             "Rate": 109
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 79,
#             "Rate": 61
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 77,
#             "Rate": 88
#         }
#     ]
# }
# {
#     "_id": 9,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "893-421-2922",
#         "786-231-9620",
#         "501-218-5126"
#     ],
#     "weights": [
#         373,
#         194,
#         203,
#         292,
#         95
#     ],
#     "height": 138,
#     "bp_readings": [
#         {
#             "Systolic": 123,
#             "Diastolic": 89,
#             "Rate": 60
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 108
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 84,
#             "Rate": 93
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 85,
#             "Rate": 87
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 79
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 97,
#             "Rate": 93
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 81,
#             "Rate": 64
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 87,
#             "Rate": 95
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 84,
#             "Rate": 83
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 71,
#             "Rate": 88
#         }
#     ]
# }
# {
#     "_id": 13,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "713-176-8049",
#         "496-331-4552",
#         "137-364-7076",
#         "051-030-8369"
#     ],
#     "weights": [
#         291,
#         177
#     ],
#     "height": 154,
#     "bp_readings": [
#         {
#             "Systolic": 122,
#             "Diastolic": 75,
#             "Rate": 92
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 81,
#             "Rate": 100
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 71,
#             "Rate": 78
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 82,
#             "Rate": 98
#         }
#     ]
# }
# {
#     "_id": 14,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "363-965-0725",
#         "344-924-2642"
#     ],
#     "weights": [
#         98,
#         196,
#         384
#     ],
#     "height": 190,
#     "bp_readings": [
#         {
#             "Systolic": 119,
#             "Diastolic": 88,
#             "Rate": 109
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 84,
#             "Rate": 100
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 89,
#             "Rate": 93
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 94,
#             "Rate": 74
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 98,
#             "Rate": 79
#         }
#     ]
# }
# {
#     "_id": 33,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "622-740-2217",
#         "895-898-7674",
#         "159-362-8489",
#         "667-242-9724"
#     ],
#     "weights": [
#         380,
#         197,
#         161,
#         283,
#         382
#     ],
#     "height": 116,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 79,
#             "Rate": 80
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 97,
#             "Rate": 105
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 86,
#             "Rate": 80
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 89,
#             "Rate": 109
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 94,
#             "Rate": 67
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 84,
#             "Rate": 106
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 90,
#             "Rate": 73
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 73,
#             "Rate": 72
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 94,
#             "Rate": 102
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 79,
#             "Rate": 81
#         }
#     ]
# }
# {
#     "_id": 41,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "456-669-4613",
#         "630-135-0952"
#     ],
#     "weights": [
#         313
#     ],
#     "height": 120,
#     "bp_readings": [
#         {
#             "Systolic": 110,
#             "Diastolic": 75,
#             "Rate": 96
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 78,
#             "Rate": 102
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 94,
#             "Rate": 109
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 76,
#             "Rate": 63
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 75,
#             "Rate": 81
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 93,
#             "Rate": 91
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 74,
#             "Rate": 90
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 88,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 42,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "855-871-4130",
#         "931-621-4641"
#     ],
#     "weights": [
#         96,
#         132
#     ],
#     "height": 165,
#     "bp_readings": [
#         {
#             "Systolic": 124,
#             "Diastolic": 79,
#             "Rate": 98
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 89,
#             "Rate": 62
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 99,
#             "Rate": 89
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 80,
#             "Rate": 86
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 75,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "997-540-6376",
#         "570-769-9027",
#         "774-466-1209"
#     ],
#     "weights": [
#         309
#     ],
#     "height": 172,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 89,
#             "Rate": 88
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 75,
#             "Rate": 95
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 82,
#             "Rate": 71
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 98,
#             "Rate": 88
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 73,
#             "Rate": 81
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 91,
#             "Rate": 61
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 70,
#             "Rate": 109
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 74,
#             "Rate": 63
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 83,
#             "Rate": 74
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 96,
#             "Rate": 108
#         }
#     ]
# }

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : {'$gte': 150}}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 2,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "528-130-0797",
#         "253-298-7373",
#         "898-939-6286"
#     ],
#     "weights": [
#         149,
#         326,
#         153,
#         256,
#         222
#     ],
#     "height": 139,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 71,
#             "Rate": 82
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 80,
#             "Rate": 65
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 72,
#             "Rate": 110
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 74,
#             "Rate": 106
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 94,
#             "Rate": 75
#         }
#     ]
# }
# {
#     "_id": 7,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "653-684-7515",
#         "045-819-7256"
#     ],
#     "weights": [
#         98,
#         180,
#         162,
#         379,
#         266
#     ],
#     "height": 135,
#     "bp_readings": [
#         {
#             "Systolic": 125,
#             "Diastolic": 85,
#             "Rate": 63
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 71,
#             "Rate": 97
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 108
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 95,
#             "Rate": 101
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 84,
#             "Rate": 79
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 81,
#             "Rate": 95
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 74,
#             "Rate": 103
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 94,
#             "Rate": 109
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 79,
#             "Rate": 61
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 77,
#             "Rate": 88
#         }
#     ]
# }
# {
#     "_id": 9,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "893-421-2922",
#         "786-231-9620",
#         "501-218-5126"
#     ],
#     "weights": [
#         373,
#         194,
#         203,
#         292,
#         95
#     ],
#     "height": 138,
#     "bp_readings": [
#         {
#             "Systolic": 123,
#             "Diastolic": 89,
#             "Rate": 60
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 108
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 84,
#             "Rate": 93
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 85,
#             "Rate": 87
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 79
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 97,
#             "Rate": 93
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 81,
#             "Rate": 64
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 87,
#             "Rate": 95
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 84,
#             "Rate": 83
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 71,
#             "Rate": 88
#         }
#     ]
# }
# {
#     "_id": 12,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "545-438-3955",
#         "837-914-3989"
#     ],
#     "weights": [
#         160,
#         388,
#         154,
#         312,
#         286
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 110,
#             "Diastolic": 90,
#             "Rate": 88
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 74
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 97,
#             "Rate": 109
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 78,
#             "Rate": 76
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 96,
#             "Rate": 77
#         }
#     ]
# }
# {
#     "_id": 30,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "394-907-9040",
#         "584-742-0182",
#         "652-925-6579"
#     ],
#     "weights": [
#         325,
#         270
#     ],
#     "height": 191,
#     "bp_readings": [
#         {
#             "Systolic": 113,
#             "Diastolic": 77,
#             "Rate": 104
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 86,
#             "Rate": 94
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 90,
#             "Rate": 74
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 91,
#             "Rate": 81
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 98,
#             "Rate": 106
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 73,
#             "Rate": 69
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 70,
#             "Rate": 73
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 87,
#             "Rate": 80
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 95,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 49,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "552-529-6576",
#         "546-675-3594",
#         "895-723-5862",
#         "472-705-2764"
#     ],
#     "weights": [
#         365
#     ],
#     "height": 142,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 97,
#             "Rate": 66
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 78,
#             "Rate": 105
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 82,
#             "Rate": 86
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 73,
#             "Rate": 66
#         }
#     ]
# }

# %% [markdown]
# ## Step 3: Review other possibly querries
#
# There are many ways we could use MongoDB to query the data. See here for more examples https://docs.mongodb.com/manual/tutorial/query-documents/. I'd also encourate you to experiment and try queries through the MongoDB online interface.

# %% [markdown]
# ## Use of Indices
#
# Indices can be used to improve the performance of queries. See [here](https://docs.mongodb.com/manual/indexes/) for more information on indices.
